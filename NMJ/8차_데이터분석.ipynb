# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import time
import itertools

# %%
df_x = pd.read_csv('../../DB/x_변수병합_민주.csv', encoding='CP949')
df_y = pd.read_csv('../../DB/폐기물데이터_행정구역변경_2.csv', encoding='CP949')

# %% [markdown]
# # Y값 = 종량제방식 등 혼합배출

# %%
y_1 = df_y[df_y['폐기물_종류'] == '종량제방식 등 혼합배출'].groupby(['행정구역','연도'])[['발생량']].sum().reset_index()
y_1
# Out:
#         행정구역    연도      발생량
# 0     강원_강릉시  2019  38945.5
# 1     강원_강릉시  2020  40579.7
# 2     강원_강릉시  2021  42722.3
# 3     강원_강릉시  2022  40274.5
# 4     강원_강릉시  2023  37047.4
# ...      ...   ...      ...
# 1140  충북_충주시  2019  82052.0
# 1141  충북_충주시  2020  60127.2
# 1142  충북_충주시  2021  56905.0
# 1143  충북_충주시  2022  41319.7
# 1144  충북_충주시  2023  47581.2
#
# [1145 rows x 3 columns]

# %%
y_1 = y_1[~(y_1['발생량'] == 0)]
# 855	전남_담양군	2019	0.0

# %%
y_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1144 entries, 0 to 1144
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    1144 non-null   object
#  1   연도      1144 non-null   int64
#  2   발생량     1144 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 35.8+ KB

# %%
df_merged = pd.merge(df_x, y_1, on=['행정구역', '연도'], how='inner')
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역          1144 non-null   object
#  1   시도            1144 non-null   object
#  2   시군구           1144 non-null   object
#  3   연도            1144 non-null   int64
#  4   주민등록세대수       1144 non-null   int64
#  5   총인구수          1144 non-null   int64
#  6   단독주택-계        1144 non-null   int64
#  7   아파트           1144 non-null   int64
#  8   연립주택          1144 non-null   int64
#  9   다세대주택         1144 non-null   int64
#  10  비주거용 건물 내 주택  1144 non-null   int64
#  11  단독주택비율        1144 non-null   float64
#  12  아파트비율         1144 non-null   float64
#  13  연립주택비율        1144 non-null   float64
#  14  다세대주택비율       1144 non-null   float64
#  15  비주거용주택비율      1144 non-null   float64
#  16  1인가구          1144 non-null   int64
#  17  2인가구          1144 non-null   int64
# ...

# %%
df_merged.isnull().sum()
# Out:
# 행정구역            0
# 시도              0
# 시군구             0
# 연도              0
# 주민등록세대수         0
# 총인구수            0
# 단독주택-계          0
# 아파트             0
# 연립주택            0
# 다세대주택           0
# 비주거용 건물 내 주택    0
# 단독주택비율          0
# 아파트비율           0
# 연립주택비율          0
# 다세대주택비율         0
# 비주거용주택비율        0
# 1인가구            0
# 2인가구            0
# 3인가구            0
# 4인가구            0
# 5인이상가구          0
# 총전입             0
# 총전출             0
# 순이동             0
# 발생량             0
# dtype: int64

# %%
# 비율로 변경
df_merged['1인가구비율'] = df_merged['1인가구'] / (df_merged['1인가구']+ df_merged['2인가구']+ df_merged['3인가구'] + df_merged['4인가구'] + df_merged['5인이상가구'])
df_merged['2인가구비율'] = df_merged['2인가구'] / (df_merged['1인가구']+ df_merged['2인가구']+ df_merged['3인가구'] + df_merged['4인가구'] + df_merged['5인이상가구'])
df_merged['3인가구비율'] = df_merged['3인가구'] / (df_merged['1인가구']+ df_merged['2인가구']+ df_merged['3인가구'] + df_merged['4인가구'] + df_merged['5인이상가구'])
df_merged['4인가구비율'] = df_merged['4인가구'] / (df_merged['1인가구']+ df_merged['2인가구']+ df_merged['3인가구'] + df_merged['4인가구'] + df_merged['5인이상가구'])
df_merged['5인이상가구비율'] = df_merged['5인이상가구'] / (df_merged['1인가구']+ df_merged['2인가구']+ df_merged['3인가구'] + df_merged['4인가구'] + df_merged['5인이상가구'])
df_merged.head(3)
# Out:
#      행정구역  시도  시군구    연도  주민등록세대수    총인구수  단독주택-계    아파트  연립주택  다세대주택  ...  \
# 0  강원_강릉시  강원  강릉시  2019    99086  213442   29481  50175  2919   1470  ...
# 1  강원_고성군  강원  고성군  2019    14445   27260    8764   2193   109    121  ...
# 2  강원_동해시  강원  동해시  2019    41141   90522   10461  24961  1657   1152  ...
#
#    5인이상가구    총전입    총전출   순이동      발생량    1인가구비율    2인가구비율    3인가구비율  \
# 0  3715.0  31980  30787  1193  38945.5  0.348767  0.310871  0.179677
# 1   409.0   3096   3835  -739  10402.5  0.343424  0.366152  0.165649
# 2  1580.0  10516  11039  -523  29090.5  0.291131  0.333738  0.198045
#
#      4인가구비율  5인이상가구비율
# 0  0.120346  0.040340
# 1  0.088034  0.036741
# 2  0.133457  0.043630
#
# [3 rows x 30 columns]

# %%
# 선정 피처
print(df_merged.columns)
df_merged_1 = df_merged[['행정구역','연도', '총인구수',
                         '단독주택비율', '아파트비율', '연립주택비율', '다세대주택비율', '비주거용주택비율', 
                         '1인가구비율', '2인가구비율', '3인가구비율', '4인가구비율', '5인이상가구비율',
                         '총전입', '순이동', '발생량']]
print(df_merged_1.info())
# Out:
# Index(['행정구역', '시도', '시군구', '연도', '주민등록세대수', '총인구수', '단독주택-계', '아파트', '연립주택',
#        '다세대주택', '비주거용 건물 내 주택', '단독주택비율', '아파트비율', '연립주택비율', '다세대주택비율',
#        '비주거용주택비율', '1인가구', '2인가구', '3인가구', '4인가구', '5인이상가구', '총전입', '총전출',
#        '순이동', '발생량', '1인가구비율', '2인가구비율', '3인가구비율', '4인가구비율', '5인이상가구비율'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   행정구역      1144 non-null   object
#  1   연도        1144 non-null   int64
#  2   총인구수      1144 non-null   int64
#  3   단독주택비율    1144 non-null   float64
#  4   아파트비율     1144 non-null   float64
#  5   연립주택비율    1144 non-null   float64
#  6   다세대주택비율   1144 non-null   float64
#  7   비주거용주택비율  1144 non-null   float64
#  8   1인가구비율    1144 non-null   float64
#  9   2인가구비율    1144 non-null   float64
#  10  3인가구비율    1144 non-null   float64
# ...

# %% [markdown]
# # 데이터 확인

# %%
df_merged_1.set_index(['행정구역','연도'], inplace=True)

# %%
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 19))
axes = axes.flatten()

for i, column in enumerate(df_merged_1):
    sns.histplot(df_merged_1[column], bins=40, kde=True, ax=axes[i])
    axes[i].set_title(f'{column}')
    axes[i].set_xlabel('')

plt.show()

# %%
corr = df_merged_1.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool_)) # 하단 삼각형만 남기
f, ax = plt.subplots(figsize=(12, 10))
cmap = sns.diverging_palette(220, 10, as_cmap=True) # color 설
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,square=True,annot=True, linewidths=.5, cbar_kws={"shrink": .5}) # color bar 크기 축소
plt.title('상관관계', fontsize=13)
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# # 데이터 전처리
# - 회귀용 - 로그변환(x값만), 표준화
# - 랜덤포레스트2 - raw데이터로 학습

# %%
df_merged_regg= df_merged_1.copy()
df_merged_rf= df_merged_1.copy()

# %%
print(df_merged_regg['총인구수'].describe())
df_merged_regg['ln총인구수'] = np.log(df_merged_regg['총인구수'])
print(df_merged_regg['ln총인구수'].describe())
# Out:
# count    1.144000e+03
# mean     2.633696e+05
# std      3.678272e+05
# min      8.867000e+03
# 25%      5.164625e+04
# 50%      1.476935e+05
# 75%      3.415570e+05
# max      2.394514e+06
# Name: 총인구수, dtype: float64
# count    1144.000000
# mean       11.850523
# std         1.125492
# min         9.090092
# 25%        10.852169
# 50%        11.902890
# 75%        12.741270
# max        14.688691
# Name: ln총인구수, dtype: float64

# %%
print(df_merged_regg['총전입'].describe())
df_merged_regg['ln총전입'] = np.log(df_merged_regg['총전입'])
print(df_merged_regg['ln총전입'].describe())
# Out:
# count      1144.000000
# mean      30007.634615
# std       32178.870045
# min         972.000000
# 25%        4946.250000
# 50%       18686.500000
# 75%       44890.500000
# max      183258.000000
# Name: 총전입, dtype: float64
# count    1144.000000
# mean        9.681803
# std         1.212490
# min         6.879356
# 25%         8.506382
# 50%         9.835556
# 75%        10.711981
# max        12.118650
# Name: ln총전입, dtype: float64

# %%
df_merged_regg = df_merged_regg[['행정구역', '연도', 'ln총인구수', '단독주택비율', '아파트비율', '연립주택비율', '다세대주택비율',
       '비주거용주택비율', '1인가구비율', '2인가구비율', '3인가구비율', '4인가구비율', '5인이상가구비율', 'ln총전입',
       '순이동', '발생량']]

# %% [markdown]
# # 데이터 split
# train, valid, test 비율을 60/20/20 %
# 1144(행) * 0.6 = 686.4  (686) -> 2019-2021
# 1144(행) * 0.2 = 228.8  (229) -> 2022
# 1144(행) * 0.2 = 228.8  (229) -> 2023

# %% [markdown]
# ### linear regression split

# %%
# df_merged_regg[df_merged_regg['연도']<2022].count()
reg_x_train = df_merged_regg[df_merged_regg['연도'] < 2022].iloc[:, 2:-1]
reg_y_train = df_merged_regg[df_merged_regg['연도'] < 2022][['발생량']]
reg_x_valid = df_merged_regg[df_merged_regg['연도'] == 2022].iloc[:, 2:-1]
reg_y_valid = df_merged_regg[df_merged_regg['연도'] == 2022][['발생량']]
reg_x_test = df_merged_regg[df_merged_regg['연도'] == 2023].iloc[:, 2:-1]
reg_y_test = df_merged_regg[df_merged_regg['연도'] == 2023][['발생량']]

# %% [markdown]
# - 표준화

# %%
scaler = StandardScaler()
# 훈련데이터로 변환
# scaler.fit(reg_x_train)
reg_x_train_s = scaler.fit_transform(reg_x_train)
reg_x_valid_s = scaler.transform(reg_x_valid)
reg_x_test_s = scaler.transform(reg_x_test)

# %%
# 컬럼명 유지
reg_x_train_s = pd.DataFrame(reg_x_train_s, columns = reg_x_train.columns)
reg_x_valid_s = pd.DataFrame(reg_x_valid_s, columns = reg_x_valid.columns)
reg_x_test_s = pd.DataFrame(reg_x_test_s, columns = reg_x_test.columns)

# %%
# 히스토그램그리기
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 19))
axes = axes.flatten()

for i, column in enumerate(reg_x_train_s):
    sns.histplot(reg_x_train_s[column], bins=40, kde=True, ax=axes[i])
    axes[i].set_title(f'{column}')
    axes[i].set_xlabel('')

plt.show()

# %% [markdown]
# ### randomforest split

# %%
# rf_x_train = df_merged_rf[df_merged_rf['연도'] < 2022].iloc[:, 2:-1]
# rf_y_train = df_merged_rf[df_merged_rf['연도'] < 2022][['발생량']]
# rf_x_valid = df_merged_rf[df_merged_rf['연도'] == 2022].iloc[:, 2:-1]
# rf_y_valid = df_merged_rf[df_merged_rf['연도'] == 2022][['발생량']]
# rf_x_test = df_merged_rf[df_merged_rf['연도'] == 2023].iloc[:, 2:-1]
# rf_y_test = df_merged_rf[df_merged_rf['연도'] == 2023][['발생량']]

# %% [markdown]
# # 회귀분석

# %%
x_contract = sm.add_constant(reg_x_train_s)

model = sm.OLS(reg_y_train, x_contract)
ols_model = model.fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    발생량   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     236.0
# Date:                Sun, 22 Jun 2025   Prob (F-statistic):          9.17e-232
# Time:                        00:55:12   Log-Likelihood:                -7513.2
# No. Observations:                 686   AIC:                         1.505e+04
# Df Residuals:                     673   BIC:                         1.511e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.476e+04    532.408     65.285      0.000    3.37e+04    3.58e+04
# ...

# %%
# Multicollinearity
# VIF
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(reg_x_train_s.values, i) for i in range(reg_x_train_s.shape[1])]
vif['features'] = reg_x_train_s.columns
vif.sort_values(by = 'VIF', ascending = False)
# Out:
# c:\workspace\busan\.venv\Lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#              VIF  features
# 10           inf  5인이상가구비율
# 9            inf    4인가구비율
# 8            inf    3인가구비율
# 7            inf    2인가구비율
# 6            inf    1인가구비율
# 1   1.892178e+07    단독주택비율
# 2   1.512868e+07     아파트비율
# 4   2.358067e+06   다세대주택비율
# 3   9.725640e+04    연립주택비율
# 5   1.246914e+04  비주거용주택비율
# 11  4.673009e+01     ln총전입
# 0   3.201753e+01    ln총인구수
# 12  1.447861e+00       순이동

# %%
#Feature Selection 전진 선택법

#변수 선택법
def processSubset(x,y, feature_set):
    model = sm.OLS(y,x[list(feature_set)])
    regr = model.fit()
    AIC = regr.aic
    return {"model" : regr , "AIC" : AIC}

def forward(x,y,predictors):
    remainingPredictors = [p for p in x.columns.difference(['const'])
                           if p not in predictors]
    tic=time.time()
    results=[]
    for p in remainingPredictors:
        results.append(processSubset(x=x,y=y,feature_set=predictors+[p]+
 ['const']))
    models = pd.DataFrame(results)

    bestModel = models.loc[models['AIC'].argmin()]
    toc = time.time()
    print("Processed ", models.shape[0],"models on", len(predictors)+1,
          "predictors in",(toc-tic))
    print("Selected predictors:",bestModel['model'].model.exog_names,
          'AIC : ',bestModel[0])
    return bestModel

# %%
#전진선택법 모델
def forward_model(x,y):
    fModels = pd.DataFrame(columns=["AIC","model"])
    tic = time.time()
    predictors = []
    for i in range(1,len(x.columns.difference(['const']))+1):
        forwardResult= forward(x,y,predictors)
        if i > 1:
            if forwardResult['AIC'] > fmodelBefore:
                break
        fModels.loc[i] = forwardResult
        predictors = fModels.loc[i]["model"].model.exog_names
        fmodelBefore = fModels.loc[i]["AIC"]
        predictors = [k for k in predictors if k != 'const']
    toc = time.time()
    print("Total elapesed time : ", (toc - tic), "seconds.")
    return (fModels['model'][len(fModels['model'])])

forwordBestModel=forward_model(x_contract, reg_y_train)
print(forwordBestModel.summary())
# Out:
# Processed  13 models on 1 predictors in 0.0501408576965332
# Selected predictors: ['ln총인구수', 'const'] AIC :  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB03EABA10>
# Processed  12 models on 2 predictors in 0.011603832244873047
# Selected predictors: ['ln총인구수', '단독주택비율', 'const'] AIC :  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB03F08810>
# Processed  11 models on 3 predictors in 0.010717391967773438
# Selected predictors: ['ln총인구수', '단독주택비율', '비주거용주택비율', 'const'] AIC :  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB03E596D0>
# Processed  10 models on 4 predictors in 0.008002281188964844
# Selected predictors: ['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', 'const'] AIC :  <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB03FA3E50>
# Processed  9 models on 5 predictors in 0.009769916534423828
# ...

# %%
# Processed  4 models on 10 predictors in 0.0050008296966552734
# Selected predictors: ['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', 'ln총전입', '2인가구비율', '연립주택비율', '순이동', '4인가구비율', '1인가구비율', 'const']

# %%
#Feature Selection 후진 제거법
def backward(x,y,predictors):
    tic = time.time()
    results=[]
    for combo in itertools.combinations(predictors, len(predictors)-1):
        results.append(processSubset(x,y,list(combo)+['const']))
    models = pd.DataFrame(results)
    bestModel = models.loc[models['AIC'].argmin()]
    toc = time.time()
    print("Processed",models.shape[0],"models on",len(predictors)-1,
          "predictors in",(toc - tic))
    print("Selected predictors :",bestModel['model'].model.exog_names,
          ' AIC:',bestModel[0])
    return bestModel

def backword_model(x,y):
    BModels = pd.DataFrame(columns=["AIC","model"])
    tic = time.time()
    predictors = x.columns.difference(['const'])
    BmodelBefore = processSubset(x,y,predictors)['AIC']
    while(len(predictors)>1):
        backwardResult=backward(x_contract, reg_y_train, predictors)
        if backwardResult['AIC'] > BmodelBefore:
            break
        BModels.loc[len(predictors)-1] = backwardResult
        predictors = BModels.loc[len(predictors)-1]["model"].model.exog_names
        BmodelBefore = backwardResult["AIC"]
        predictors = [ k for k in predictors if k != 'const']

    toc = time.time()
    print("Total elapsed time :",(toc - tic), "seconds.")
    return (BModels["model"].dropna().iloc[0])

backwardBestModel = backword_model(x_contract, reg_y_train)
print(backwardBestModel.summary())
# Out:
# Processed 13 models on 12 predictors in 0.03453683853149414
# Selected predictors : ['1인가구비율', '2인가구비율', '3인가구비율', '4인가구비율', '5인이상가구비율', 'ln총인구수', 'ln총전입', '단독주택비율', '비주거용주택비율', '순이동', '아파트비율', '연립주택비율', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB0408E790>
# Processed 12 models on 11 predictors in 0.011379718780517578
# Selected predictors : ['1인가구비율', '2인가구비율', '3인가구비율', '4인가구비율', 'ln총인구수', 'ln총전입', '단독주택비율', '비주거용주택비율', '순이동', '아파트비율', '연립주택비율', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB040D6250>
# Processed 11 models on 10 predictors in 0.009362459182739258
# Selected predictors : ['1인가구비율', '2인가구비율', '4인가구비율', 'ln총인구수', 'ln총전입', '단독주택비율', '비주거용주택비율', '순이동', '아파트비율', '연립주택비율', 'const']  AIC: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001EB040D5B10>
# Processed 10 models on 9 predictors in 0.006914377212524414
# ...

# %%
new_reg_x_train_s = reg_x_train_s[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율',  '4인가구비율', 'ln총전입', '순이동']]
new_x_contract = sm.add_constant(new_reg_x_train_s)

model2 = sm.OLS(reg_y_train, new_x_contract)
ols_model2 = model2.fit()
ols_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    발생량   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     284.0
# Date:                Sun, 22 Jun 2025   Prob (F-statistic):          3.30e-234
# Time:                        01:19:13   Log-Likelihood:                -7513.2
# No. Observations:                 686   AIC:                         1.505e+04
# Df Residuals:                     675   BIC:                         1.510e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.476e+04    531.635     65.380      0.000    3.37e+04    3.58e+04
# ...

# %%
# Multicollinearity
# VIF
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(new_reg_x_train_s.values, i) for i in range(new_reg_x_train_s.shape[1])]
vif['features'] = new_reg_x_train_s.columns
vif.sort_values(by = 'VIF', ascending = False)
# Out:
#           VIF  features
# 7  138.441659    4인가구비율
# 6   61.190820    2인가구비율
# 8   46.177327     ln총전입
# 5   43.953434    1인가구비율
# 0   31.529120    ln총인구수
# 1   12.079638    단독주택비율
# 3    1.903868   다세대주택비율
# 2    1.870371  비주거용주택비율
# 9    1.399549       순이동
# 4    1.333396    연립주택비율

# %%
'ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율', '순이동']]
AIC:	1.509e+04
Df Residuals:	677	BIC:	1.513e+04
0.794  0.792
'ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율'
AIC:	1.509e+04
Df Residuals:	678	BIC:	1.513e+04
0.794 0.792


[['ln총인구수', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율', '순이동']]
AIC:	1.513e+04
Df Residuals:	678	BIC:	1.517e+04
0.781 0.779

[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '2인가구비율', '순이동']]
AIC:	1.510e+04
Df Residuals:	678	BIC:	1.513e+04
0.793 0.791
#  ----
# 다중공선성은 높고
[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율', 'ln총전입', '순이동']]
AIC:	1.506e+04
Df Residuals:	676	BIC:	1.511e+04
0.804 0.801

[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '2인가구비율', 'ln총전입', '순이동']]
AIC:	1.506e+04
Df Residuals:	677	BIC:	1.510e+04
0.804 0.801


AIC의 감소는 모델의 적합도가 향상되었음을 나타냄. 복잡성의 증가에도 전반적으로 더 나은 모델이라함
하지만 다중공선성의 증가도 막아야함함 변수가 많으면 당연히 더 잘 설명할수잇지만 과적합되는것임

# %%
new2_reg_x_train_s = reg_x_train_s[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]
new2_x_contract = sm.add_constant(new2_reg_x_train_s)

model2 = sm.OLS(reg_y_train, new2_x_contract)
ols_model2 = model2.fit()
ols_model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    발생량   R-squared:                       0.794
# Model:                            OLS   Adj. R-squared:                  0.792
# Method:                 Least Squares   F-statistic:                     373.1
# Date:                Sun, 22 Jun 2025   Prob (F-statistic):          1.04e-227
# Time:                        17:17:58   Log-Likelihood:                -7537.5
# No. Observations:                 686   AIC:                         1.509e+04
# Df Residuals:                     678   BIC:                         1.513e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.476e+04    549.511     63.253      0.000    3.37e+04    3.58e+04
# ...

# %%
규모를 따져야할때

쓰레기량/인구수 

ln.인구수 + 비율피처들  = 쓰레기량

r을 높은 거 vs 변수 선택을 중심으로 
변수 vif

# %%
# Multicollinearity
# VIF|
vif = pd.DataFrame()
vif["VIF"] = [variance_inflation_factor(new2_reg_x_train_s.values, i) for i in range(new2_reg_x_train_s.shape[1])]
vif['features'] = new2_reg_x_train_s.columns
vif.sort_values(by = 'VIF', ascending = False)
# Out:
#         VIF  features
# 1  9.934389    단독주택비율
# 6  7.947763    2인가구비율
# 0  4.055213    ln총인구수
# 2  1.826749  비주거용주택비율
# 5  1.808541    1인가구비율
# 3  1.613463   다세대주택비율
# 4  1.266245    연립주택비율

# %%
# ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율'

# %%
new2_reg_x_train_s = reg_x_train_s[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]
new2_reg_x_valid_s = reg_x_valid_s[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]
new2_reg_x_test_s = reg_x_test_s[['ln총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]

# %%
model_reg = LinearRegression()
model_reg.fit(new2_reg_x_train_s, reg_y_train)
# Out:
# LinearRegression()

# %%
predictions = model_reg.predict(new2_reg_x_valid_s)

mse = mean_squared_error(reg_y_valid, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(reg_y_valid, predictions)
mae = mean_absolute_error(reg_y_valid, predictions)
print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, R^2: {r2:.4f}, MAE: {mae:.4f}")

model_performance = {}
model_performance["Regression"] = {
    'MSE': mse,
    'RMSE': rmse,
    'R^2': r2,
    'MAE': mae
}
# Out:
# MSE: 208459483.1716, RMSE: 14438.1260, R^2: 0.8078, MAE: 10307.0275

# %%
new_2_rf_x_train = rf_x_train[['총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]
new_2_rf_x_valid = rf_x_valid[['총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]
new_2_rf_x_test = rf_x_test[['총인구수', '단독주택비율', '비주거용주택비율', '다세대주택비율', '연립주택비율', '1인가구비율', '2인가구비율']]

# %%
model_rf = RandomForestRegressor(random_state=42)
model_rf.fit(new_2_rf_x_train, rf_y_train)
# Out:
# c:\workspace\busan\.venv\Lib\site-packages\sklearn\base.py:1363: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
predictions = model_rf.predict(new_2_rf_x_valid)
mse = mean_squared_error(rf_y_valid, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(rf_y_valid, predictions)
mae = mean_absolute_error(rf_y_valid, predictions)
print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, R^2: {r2:.4f}, MAE: {mae:.4f}")

model_performance["Randomforest"] = {
    'MSE': mse,
    'RMSE': rmse,
    'R^2': r2,
    'MAE': mae
}
# Out:
# MSE: 41331388.1318, RMSE: 6428.9492, R^2: 0.9619, MAE: 3831.6113

# %%
model_rf_standard = RandomForestRegressor(random_state=42)
model_rf_standard.fit(rf_x_train, rf_y_train)
# Out:
# c:\workspace\busan\.venv\Lib\site-packages\sklearn\base.py:1363: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=42)

# %%
predictions = model_rf_standard.predict(rf_x_valid)
mse = mean_squared_error(rf_y_valid, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(rf_y_valid, predictions)
mae = mean_absolute_error(rf_y_valid, predictions)
print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, R^2: {r2:.4f}, MAE: {mae:.4f}")
# Out:
# MSE: 47790589.7267, RMSE: 6913.0738, R^2: 0.9559, MAE: 4360.2960

# %%
# 변환을 한 reg로 랜덤포레스트 해보기 (호기심...)
model_rf_reg = RandomForestRegressor(random_state=42)
model_rf_reg.fit(new2_reg_x_train_s, reg_y_train)
predictions = model_rf_reg.predict(new2_reg_x_valid_s)
mse = mean_squared_error(reg_y_valid, predictions)
rmse = np.sqrt(mse)
r2 = r2_score(reg_y_valid, predictions)
mae = mean_absolute_error(reg_y_valid, predictions)
print(f"MSE: {mse:.4f}, RMSE: {rmse:.4f}, R^2: {r2:.4f}, MAE: {mae:.4f}")
# Out:
# c:\workspace\busan\.venv\Lib\site-packages\sklearn\base.py:1363: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# MSE: 41371659.6024, RMSE: 6432.0805, R^2: 0.9618, MAE: 3846.6259

# %%
final_reg_predictions_test = model_reg.predict(new2_reg_x_test_s)

mse_test_reg = mean_squared_error(reg_y_test, final_reg_predictions_test)
rmse_test_reg = np.sqrt(mse_test_reg)
r2_test_reg = r2_score(reg_y_test, final_reg_predictions_test)
mae_test_reg = mean_absolute_error(reg_y_test, final_reg_predictions_test)

print("\n--- Linear Regression Final Test Set Performance ---")
print(f"MSE: {mse_test_reg:.4f}, RMSE: {rmse_test_reg:.4f}, R^2: {r2_test_reg:.4f}, MAE: {mae_test_reg:.4f}")

model_performance["Regression_Test"] = {
    'MSE': mse_test_reg,
    'RMSE': rmse_test_reg,
    'R^2': r2_test_reg,
    'MAE': mae_test_reg
}


# final_rf_predictions_test = model_rf.predict(new_2_rf_x_test) # 이 변수명도 확인!

# mse_test_rf = mean_squared_error(rf_y_test, final_rf_predictions_test)
# rmse_test_rf = np.sqrt(mse_test_rf)
# r2_test_rf = r2_score(rf_y_test, final_rf_predictions_test)
# mae_test_rf = mean_absolute_error(rf_y_test, final_rf_predictions_test)

# print("\n--- RandomForest Final Test Set Performance ---")
# print(f"MSE: {mse_test_rf:.4f}, RMSE: {rmse_test_rf:.4f}, R^2: {r2_test_rf:.4f}, MAE: {mae_test_rf:.4f}")

# model_performance["RandomForest_Test"] = {
#     'MSE': mse_test_rf,
#     'RMSE': rmse_test_rf,
#     'R^2': r2_test_rf,
#     'MAE': mae_test_rf
# }



final_rf_predictions_test = model_rf_reg.predict(new2_reg_x_test_s) # 이 변수명도 확인!

mse_test_rf = mean_squared_error(reg_y_test, final_rf_predictions_test)
rmse_test_rf = np.sqrt(mse_test_rf)
r2_test_rf = r2_score(reg_y_test, final_rf_predictions_test)
mae_test_rf = mean_absolute_error(reg_y_test, final_rf_predictions_test)

print("\n--- RandomForest Final Test Set Performance ---")
print(f"MSE: {mse_test_rf:.4f}, RMSE: {rmse_test_rf:.4f}, R^2: {r2_test_rf:.4f}, MAE: {mae_test_rf:.4f}")

model_performance["RandomForest_Test(regdata)"] = {
    'MSE': mse_test_rf,
    'RMSE': rmse_test_rf,
    'R^2': r2_test_rf,
    'MAE': mae_test_rf
}
# Out:
# --- Linear Regression Final Test Set Performance ---
# MSE: 232471155.9781, RMSE: 15247.0048, R^2: 0.7965, MAE: 10366.1336
#
# --- RandomForest Final Test Set Performance ---
# MSE: 79132615.3639, RMSE: 8895.6515, R^2: 0.9307, MAE: 4777.4157

# %%
df_merged_busan['발생량']

final_rf_predictions_test = model_rf_reg.predict(new2_reg_x_test_s) # 이 변수명도 확인!

mse_test_rf = mean_squared_error(reg_y_test, final_rf_predictions_test)
rmse_test_rf = np.sqrt(mse_test_rf)
r2_test_rf = r2_score(reg_y_test, final_rf_predictions_test)
mae_test_rf = mean_absolute_error(reg_y_test, final_rf_predictions_test)

print("\n--- RandomForest Final Test Set Performance ---")
print(f"MSE: {mse_test_rf:.4f}, RMSE: {rmse_test_rf:.4f}, R^2: {r2_test_rf:.4f}, MAE: {mae_test_rf:.4f}")

# %%
# - 교차검증해보기

# %%
from sklearn.model_selection import cross_val_score

# 튜닝된 모델이 있다면 튜닝된 모델을 사용, 없다면 기본 모델 사용
# model_to_evaluate = model_rf # 튜닝 전
model_to_evaluate = model_rf_reg # 튜닝 후

# 5-겹 교차 검증으로 R^2 스코어 계산
# 이때도 OLS에서 선택된 변수들로 구성된 스케일링된 x_train을 사용합니다.
scores = cross_val_score(model_to_evaluate, new2_reg_x_train_s, reg_y_train, cv=5, scoring='r2', n_jobs=-1)

print(f"\nCross-validation R^2 scores: {scores}")
print(f"Mean R^2: {scores.mean():.4f}")
print(f"Standard deviation of R^2: {scores.std():.4f}")

# RMSE도 확인하고 싶다면 scoring을 'neg_mean_squared_error'로 변경 후 sqrt 적용
rmse_scores = np.sqrt(-cross_val_score(model_to_evaluate, new2_reg_x_train_s, reg_y_train, cv=5, scoring='neg_mean_squared_error', n_jobs=-1))
print(f"Cross-validation RMSE scores: {rmse_scores}")
print(f"Mean RMSE: {rmse_scores.mean():.4f}")
print(f"Standard deviation of RMSE: {rmse_scores.std():.4f}")
# Out:
# Cross-validation R^2 scores: [0.93223893 0.94182052 0.97445025 0.96018564 0.92998081]
# Mean R^2: 0.9477
# Standard deviation of R^2: 0.0171
# Cross-validation RMSE scores: [7885.5465574  8132.57125114 4194.2814319  7453.21504217 7599.38724366]
# Mean RMSE: 7053.0003
# Standard deviation of RMSE: 1448.4192

# %%
# y값 log

# %%
new_2_rf_x_test
# Out:
#          총인구수  단독주택비율  비주거용주택비율  다세대주택비율  연립주택비율    1인가구비율    2인가구비율
# 915    209439  0.3269    0.0200   0.0162  0.0360  0.397794  0.319002
# 916     27305  0.6840    0.0280   0.0114  0.0116  0.415669  0.353801
# 917     88625  0.2464    0.0165   0.0282  0.0394  0.358402  0.339689
# 918     62651  0.4190    0.0190   0.0297  0.0509  0.419653  0.338892
# 919     82054  0.2021    0.0153   0.0131  0.0457  0.387940  0.329688
# ...       ...     ...       ...      ...     ...       ...       ...
# 1139   130194  0.3674    0.0235   0.0173  0.0325  0.381252  0.339783
# 1140    37484  0.2407    0.0161   0.0162  0.0276  0.394765  0.296748
# 1141    86254  0.2725    0.0113   0.0787  0.0407  0.378368  0.296712
# 1142  1704378  0.1933    0.0124   0.0190  0.0145  0.380597  0.267308
# 1143   207778  0.3156    0.0172   0.0530  0.0321  0.391387  0.318671
#
# [229 rows x 7 columns]

# %%
b = df_merged_rf.iloc[915:][['행정구역','발생량']]
b
# Out:
#         행정구역       발생량
# 915   강원_강릉시   37047.4
# 916   강원_고성군   12409.1
# 917   강원_동해시   25916.0
# 918   강원_삼척시   23517.2
# 919   강원_속초시   20025.5
# ...      ...       ...
# 1139  충북_제천시   32360.0
# 1140  충북_증평군    8873.2
# 1141  충북_진천군   18595.1
# 1142  충북_청주시  172274.8
# 1143  충북_충주시   47581.2
#
# [229 rows x 2 columns]

# %%
a = pd.DataFrame(final_rf_predictions_test)
a.rename(columns={0: '새로운_발생량'}, inplace=True)
a
# Out:
#         새로운_발생량
# 0     47835.386
# 1     10634.649
# 2     27482.565
# 3     15793.130
# 4     26073.876
# ..          ...
# 224   31845.217
# 225    8555.629
# 226   15710.262
# 227  170938.165
# 228   55189.255
#
# [229 rows x 1 columns]

# %%
df_b_reset = b.reset_index(drop=True)
df_a_reset = a.reset_index(drop=True)
df_merged = pd.concat([df_b_reset, df_a_reset], axis=1)

# %%
df_merged
# Out:
#        행정구역       발생량     새로운_발생량
# 0    강원_강릉시   37047.4   47835.386
# 1    강원_고성군   12409.1   10634.649
# 2    강원_동해시   25916.0   27482.565
# 3    강원_삼척시   23517.2   15793.130
# 4    강원_속초시   20025.5   26073.876
# ..      ...       ...         ...
# 224  충북_제천시   32360.0   31845.217
# 225  충북_증평군    8873.2    8555.629
# 226  충북_진천군   18595.1   15710.262
# 227  충북_청주시  172274.8  170938.165
# 228  충북_충주시   47581.2   55189.255
#
# [229 rows x 3 columns]

# %%
df_merged_busan = df_merged[df_merged['행정구역'].str.startswith('부산_')]
df_merged_busan
# Out:
#         행정구역      발생량    새로운_발생량
# 108   부산_강서구  17160.4  21337.761
# 109   부산_금정구  32190.5  23652.717
# 110   부산_기장군  30226.6  26754.043
# 111    부산_남구  31821.2  25465.191
# 112    부산_동구  14990.3  12378.538
# 113   부산_동래구  25182.0  24674.468
# 114  부산_부산진구  60952.1  44199.025
# 115    부산_북구  27999.9  24755.693
# 116   부산_사상구  19262.1  21935.675
# 117   부산_사하구  40109.1  32402.914
# 118    부산_서구  13402.8  11038.795
# 119   부산_수영구  22684.7  19674.304
# 120   부산_연제구  27892.3  20361.453
# 121   부산_영도구  15842.1  12649.114
# 122    부산_중구  19162.0  12519.801
# 123  부산_해운대구  37971.8  42962.965

# %%
df_merged_busan['오차(실제값기준)'] = df_merged_busan['발생량'] - df_merged_busan['새로운_발생량']
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_9096\852196703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_merged_busan['오차(실제값기준)'] = df_merged_busan['발생량'] - df_merged_busan['새로운_발생량']

# %%
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family']='Malgun Gothic'

# %%
# 시군구별 예측값/실제값 형태 변환
df_plot = df_merged_busan[['행정구역', '새로운_발생량', '발생량']].melt(id_vars='행정구역', var_name='구분', value_name='값')

# 시군구 이름 기준 정렬
order = df_merged_busan.sort_values(by='발생량', ascending=False)['행정구역']

plt.figure(figsize=(12, 6))
sns.lineplot(data=df_plot, x='행정구역', y='값', hue='구분', style='구분', markers=True, dashes=False, sort=False)
plt.xticks(rotation=45)
plt.title('2023년 부산 행정구역별 발생량 vs 	새로운_발생량')
plt.ylabel('재활용 처리량 (혼합배출 기준)')
plt.xlabel('행정구역')
plt.tight_layout()
plt.legend(title='구분')
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_9096\2317015294.py:13: UserWarning: Glyph 9 (	) missing from font(s) Malgun Gothic.
#   plt.tight_layout()
# c:\workspace\busan\.venv\Lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 9 (	) missing from font(s) Malgun Gothic.
#   func(*args, **kwargs)
# c:\workspace\busan\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) Malgun Gothic.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
df_sorted_heatmap = df_merged_busan.sort_values(by='오차(실제값기준)', ascending=False)
sns.barplot(data=df_sorted_heatmap, x='행정구역', y='오차(실제값기준)', palette='summer')
plt.xticks(rotation=45)
plt.title('2023년 부산 시군구별 예측 오차 (실제값 기준)')
plt.ylabel('예측 오차 (실제값 - 예측값)')
plt.xlabel('시군구')
plt.axhline(0, color='gray', linestyle='--')
plt.tight_layout()
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_9096\2254255457.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_sorted_heatmap, x='행정구역', y='오차(실제값기준)', palette='summer')

# %%
df_merged_busan['오차(실제값기준)'].describe()
# Out:
# count       16.000000
# mean      3755.465187
# std       5369.905260
# min      -4991.165000
# 25%       1899.886750
# 50%       3218.596500
# 75%       6864.361000
# max      16753.075000
# Name: 오차(실제값기준), dtype: float64
