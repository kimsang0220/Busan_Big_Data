# %%
import pandas as pd
import numpy as np

# %%
bori_waste = pd.read_csv('../../DB/자원순환정보시스템_시군구별_폐기물배출량.csv', encoding = 'CP949')
sh_waste = pd.read_csv('../../DB/sh_waste.csv', encoding='utf-8')

# %%
bori_waste
# Out:
#       Unnamed: 0       지역    연도 시ㆍ도   시군구  배출량(톤/년)
# 0              0   서울_종로구  2024  서울   종로구  31941.99
# 1              1    서울_중구  2024  서울    중구  39154.08
# 2              2   서울_용산구  2024  서울   용산구  31272.54
# 3              3   서울_성동구  2024  서울   성동구  25274.96
# 4              4   서울_광진구  2024  서울   광진구  25437.48
# ...          ...      ...   ...  ..   ...       ...
# 1391        1391   경남_함양군  2019  경남   함양군   8019.72
# 1392        1392   경남_거창군  2019  경남   거창군  14227.88
# 1393        1393   경남_합천군  2019  경남   합천군   8027.84
# 1394        1394   제주_제주시  2019  제주   제주시  66896.53
# 1395        1395  제주_서귀포시  2019  제주  서귀포시  14792.02
#
# [1396 rows x 6 columns]

# %%
sh_waste
# Out:
#        시도   시군구          폐기물_종류  폐기물_종류1   폐기물_종류2      재활용      소각      매립  \
# 0      서울   종로구    종량제방식 등 혼합배출      가연성       폐지류      0.0  9125.0  4672.0
# 1      서울   종로구    종량제방식 등 혼합배출      가연성    폐합성수지류      0.0  5365.5  2737.5
# 2      서울   종로구    종량제방식 등 혼합배출      가연성      폐고무류      0.0   182.5    73.0
# 3      서울   종로구    종량제방식 등 혼합배출      가연성      폐섬유류      0.0   511.0   255.5
# 4      서울   종로구    종량제방식 등 혼합배출      가연성  음식물류 폐기물      0.0   693.5   365.0
# ...    ..   ...             ...      ...       ...      ...     ...     ...
# 42471  제주  서귀포시  재활용 가능자원  분리배출  폐전기전자제품       NaN   1027.6     0.0     0.0
# 42472  제주  서귀포시  재활용 가능자원  분리배출     폐가구류       NaN      0.0     0.0     0.0
# 42473  제주  서귀포시  재활용 가능자원  분리배출       기타       NaN    200.0     0.0     0.0
# 42474  제주  서귀포시  재활용 가능자원  분리배출  재활용 잔재물       NaN      0.0  1627.4   718.0
# 42475  제주  서귀포시   음식물류 폐기물 분리배출      NaN       NaN  30650.4     0.0     0.0
#
#         기타      발생량    연도
# 0      0.0  13797.0  2019
# 1      0.0   8103.0  2019
# 2      0.0    255.5  2019
# 3      0.0    766.5  2019
# 4      0.0   1058.5  2019
# ...    ...      ...   ...
# 42471  0.0   1027.6  2023
# 42472  0.0      0.0  2023
# 42473  0.0    200.0  2023
# 42474  0.0   2345.4  2023
# 42475  0.0  30650.4  2023
#
# [42476 rows x 11 columns]

# %% [markdown]
# # 세종_세종시 바꾸기
# - 시도
# - 시군구

# %%
sh_waste[sh_waste['시도'] == '세종']
# Out:
#        시도  시군구          폐기물_종류  폐기물_종류1   폐기물_종류2      재활용      소각     매립  \
# 2775   세종  세종시    종량제방식 등 혼합배출      가연성       폐지류   1131.5  8942.5  766.5
# 2776   세종  세종시    종량제방식 등 혼합배출      가연성    폐합성수지류    876.0  6935.0  584.0
# 2777   세종  세종시    종량제방식 등 혼합배출      가연성      폐고무류     36.5   438.0   36.5
# 2778   세종  세종시    종량제방식 등 혼합배출      가연성      폐섬유류    182.5  1314.0  109.5
# 2779   세종  세종시    종량제방식 등 혼합배출      가연성  음식물류 폐기물    219.0  1715.5  146.0
# ...    ..  ...             ...      ...       ...      ...     ...    ...
# 36810  세종  세종시  재활용 가능자원  분리배출  폐전기전자제품       NaN    703.9     0.0    0.0
# 36811  세종  세종시  재활용 가능자원  분리배출     폐가구류       NaN      0.0     0.0    0.0
# 36812  세종  세종시  재활용 가능자원  분리배출       기타       NaN     89.0     0.0    0.0
# 36813  세종  세종시  재활용 가능자원  분리배출  재활용 잔재물       NaN    881.0     0.0    0.0
# 36814  세종  세종시   음식물류 폐기물 분리배출      NaN       NaN  15341.0     0.0    0.0
#
#            기타      발생량    연도
# 2775   1022.0  11862.5  2019
# 2776    766.5   9161.5  2019
# 2777     36.5    547.5  2019
# 2778    146.0   1752.0  2019
# 2779    182.5   2263.0  2019
# ...       ...      ...   ...
# 36810     0.0    703.9  2023
# 36811     0.0      0.0  2023
# 36812     0.0     89.0  2023
# 36813     0.0    881.0  2023
# 36814     0.0  15341.0  2023
#
# [185 rows x 11 columns]

# %%
# sh_waste.to_csv('DB/상현_폐기물데이터_행정구역변경.csv',encoding = 'CP949', index=False)

# %%
sh_waste = pd.read_csv('DB/상현_폐기물데이터_행정구역변경.csv', encoding='CP949')

# %%
print(set(bori_waste['지역'].unique())-set(sh_waste['행정구역'].unique()))
print(set(sh_waste['행정구역'].unique()) - set(bori_waste['지역'].unique()))
# Out:
# {'인천_영종경제청', '인천_송도경제청', '인천_청라경제청'}
# set()

# %%
# 상현님 폐기물 
#  경북 군위군, 대구_군위군

# %%
sh_waste[sh_waste['행정구역'] == '대구_군위군']
# Out:
#          행정구역  시도  시군구          폐기물_종류    폐기물_종류1          폐기물_종류2     재활용  \
# 35816  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성              폐지류     0.0
# 35817  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성           폐합성수지류     0.0
# 35818  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성             폐고무류     0.0
# 35819  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성             폐섬유류     0.0
# 35820  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성         음식물류 폐기물     0.0
# 35821  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성             폐목재류     0.0
# 35822  대구_군위군  대구  군위군    종량제방식 등 혼합배출        가연성               기타     0.0
# 35823  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성             폐금속류     0.0
# 35824  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성             폐유리류     0.0
# 35825  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성             폐토사류     0.0
# 35826  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성       폐타일 및 도자기류     0.0
# 35827  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성              연탄재     0.0
# 35828  대구_군위군  대구  군위군    종량제방식 등 혼합배출        불연성               기타     0.0
# 35829  대구_군위군  대구  군위군    종량제방식 등 혼합배출      건설폐재류  건설폐재류(공사장생활폐기물)     0.0
# 35830  대구_군위군  대구  군위군    종량제방식 등 혼합배출  기타(배출불명등)              NaN     0.0
# 35831  대구_군위군  대구  군위군  재활용 가능자원  분리배출        폐지류              종이팩     0.0
# 35832  대구_군위군  대구  군위군  재활용 가능자원  분리배출        폐지류               기타   148.3
# 35833  대구_군위군  대구  군위군  재활용 가능자원  분리배출        고철류              NaN    25.4
# 35834  대구_군위군  대구  군위군  재활용 가능자원  분리배출        금속캔              NaN    17.0
# 35835  대구_군위군  대구  군위군  재활용 가능자원  분리배출     폐합성수지류              비닐류    20.0
# 35836  대구_군위군  대구  군위군  재활용 가능자원  분리배출     폐합성수지류            발포수지류     0.0
# 35837  대구_군위군  대구  군위군  재활용 가능자원  분리배출     폐합성수지류             PET병    21.1
# 35838  대구_군위군  대구  군위군  재활용 가능자원  분리배출     폐합성수지류               기타    18.4
# 35839  대구_군위군  대구  군위군  재활용 가능자원  분리배출       폐고무류              NaN     0.0
# 35840  대구_군위군  대구  군위군  재활용 가능자원  분리배출      폐유리병류              NaN    33.7
# 35841  대구_군위군  대구  군위군  재활용 가능자원  분리배출        폐의류              NaN    22.0
# 35842  대구_군위군  대구  군위군  재활용 가능자원  분리배출       폐섬유류              NaN     0.0
# 35843  대구_군위군  대구  군위군  재활용 가능자원  분리배출      조명폐기물              NaN     0.0
# 35844  대구_군위군  대구  군위군  재활용 가능자원  분리배출       폐전지류              NaN     1.9
# 35845  대구_군위군  대구  군위군  재활용 가능자원  분리배출      영농폐기물            농약용기류    12.9
# 35846  대구_군위군  대구  군위군  재활용 가능자원  분리배출      영농폐기물              폐비닐  1207.6
# 35847  대구_군위군  대구  군위군  재활용 가능자원  분리배출       폐식용유              NaN     0.0
# 35848  대구_군위군  대구  군위군  재활용 가능자원  분리배출    폐전기전자제품              NaN   277.0
# 35849  대구_군위군  대구  군위군  재활용 가능자원  분리배출       폐가구류              NaN     0.0
# 35850  대구_군위군  대구  군위군  재활용 가능자원  분리배출         기타              NaN     0.0
# 35851  대구_군위군  대구  군위군  재활용 가능자원  분리배출    재활용 잔재물              NaN     0.0
# 35852  대구_군위군  대구  군위군   음식물류 폐기물 분리배출        NaN              NaN   549.6
#
#            소각      매립   기타     발생량    연도
# 35816   601.5   883.5  0.0  1485.0  2023
# 35817   988.1  1451.3  0.0  2439.4  2023
# 35818    46.2    67.8  0.0   114.0  2023
# 35819   118.1   173.4  0.0   291.5  2023
# 35820   245.5   360.7  0.0   606.2  2023
# 35821    56.6    83.1  0.0   139.7  2023
# 35822  1045.0  1535.0  0.0  2580.0  2023
# 35823    45.2    66.3  0.0   111.5  2023
# 35824    89.6   131.6  0.0   221.2  2023
# 35825    10.1    14.8  0.0    24.9  2023
# 35826     6.6     9.7  0.0    16.3  2023
# 35827     0.0     0.0  0.0     0.0  2023
# 35828   217.1   318.8  0.0   535.9  2023
# 35829     3.4    33.3  0.0    36.7  2023
# 35830     0.0     0.0  0.0     0.0  2023
# 35831     0.0     0.0  0.0     0.0  2023
# 35832     0.0     0.0  0.0   148.3  2023
# 35833     0.0     0.0  0.0    25.4  2023
# 35834     0.0     0.0  0.0    17.0  2023
# 35835     0.0     0.0  0.0    20.0  2023
# 35836     0.0     0.0  0.0     0.0  2023
# 35837     0.0     0.0  0.0    21.1  2023
# 35838     0.0     0.0  0.0    18.4  2023
# 35839     0.0     0.0  0.0     0.0  2023
# 35840     0.0     0.0  0.0    33.7  2023
# 35841     0.0     0.0  0.0    22.0  2023
# 35842     0.0     0.0  0.0     0.0  2023
# 35843     0.0     0.0  0.0     0.0  2023
# 35844     0.0     0.0  0.0     1.9  2023
# 35845     0.0     0.0  0.0    12.9  2023
# 35846     0.0     0.0  0.0  1207.6  2023
# 35847     0.0     0.0  0.0     0.0  2023
# 35848     0.0     0.0  0.0   277.0  2023
# 35849     0.0     0.0  0.0     0.0  2023
# 35850     0.0     0.0  0.0     0.0  2023
# 35851     0.0     0.0  0.0     0.0  2023
# 35852   152.8     0.0  0.0   702.4  2023

# %%
sh_waste[sh_waste['행정구역'] == '경북_군위군']
# Out:
#          행정구역  시도  시군구          폐기물_종류  폐기물_종류1   폐기물_종류2    재활용      소각  \
# 7289   경북_군위군  경북  군위군    종량제방식 등 혼합배출      가연성       폐지류  255.5   182.5
# 7290   경북_군위군  경북  군위군    종량제방식 등 혼합배출      가연성    폐합성수지류  109.5  1314.0
# 7291   경북_군위군  경북  군위군    종량제방식 등 혼합배출      가연성      폐고무류    0.0   401.5
# 7292   경북_군위군  경북  군위군    종량제방식 등 혼합배출      가연성      폐섬유류    0.0     0.0
# 7293   경북_군위군  경북  군위군    종량제방식 등 혼합배출      가연성  음식물류 폐기물    0.0     0.0
# ...       ...  ..  ...             ...      ...       ...    ...     ...
# 32814  경북_군위군  경북  군위군  재활용 가능자원  분리배출  폐전기전자제품       NaN   78.0     0.0
# 32815  경북_군위군  경북  군위군  재활용 가능자원  분리배출     폐가구류       NaN    0.0     0.0
# 32816  경북_군위군  경북  군위군  재활용 가능자원  분리배출       기타       NaN    0.0     0.0
# 32817  경북_군위군  경북  군위군  재활용 가능자원  분리배출  재활용 잔재물       NaN    0.0     0.0
# 32818  경북_군위군  경북  군위군   음식물류 폐기물 분리배출      NaN       NaN  661.1     0.0
#
#           매립   기타     발생량    연도
# 7289     0.0  0.0   438.0  2019
# 7290   292.0  0.0  1715.5  2019
# 7291   109.5  0.0   511.0  2019
# 7292     0.0  0.0     0.0  2019
# 7293     0.0  0.0     0.0  2019
# ...      ...  ...     ...   ...
# 32814    0.0  0.0    78.0  2022
# 32815    0.0  0.0     0.0  2022
# 32816    0.0  0.0     0.0  2022
# 32817    0.0  0.0     0.0  2022
# 32818    0.0  3.0   664.1  2022
#
# [148 rows x 12 columns]

# %%
# 경북_군위군 -> 대구 군위군으로 통일

# %%
sh_waste['시도'][sh_waste['행정구역'] == '경북_군위군'] = "대구"
sh_waste['행정구역'][sh_waste['행정구역'] == '경북_군위군'] = "대구_군위군"
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\410252997.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   sh_waste['시도'][sh_waste['행정구역'] == '경북_군위군'] = "대구"
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\410252997.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sh_waste['시도'][sh_waste['행정구역'] == '경북_군위군'] = "대구"
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\410252997.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   sh_waste['행정구역'][sh_waste['행정구역'] == '경북_군위군'] = "대구_군위군"
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\410252997.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sh_waste['행정구역'][sh_waste['행정구역'] == '경북_군위군'] = "대구_군위군"

# %%
# sh_waste.to_csv('DB/상현_폐기물데이터_행정구역변경(수정).csv',encoding = 'CP949', index=False)

# %%
waste = pd.read_csv('../../DB/폐기물데이터_행정구역변경_2.csv', encoding = 'CP949')

# %%
waste
# Out:
#           행정구역  시도   시군구          폐기물_종류  폐기물_종류1   폐기물_종류2      재활용      소각  \
# 0       서울_종로구  서울   종로구    종량제방식 등 혼합배출      가연성       폐지류      0.0  9125.0
# 1       서울_종로구  서울   종로구    종량제방식 등 혼합배출      가연성    폐합성수지류      0.0  5365.5
# 2       서울_종로구  서울   종로구    종량제방식 등 혼합배출      가연성      폐고무류      0.0   182.5
# 3       서울_종로구  서울   종로구    종량제방식 등 혼합배출      가연성      폐섬유류      0.0   511.0
# 4       서울_종로구  서울   종로구    종량제방식 등 혼합배출      가연성  음식물류 폐기물      0.0   693.5
# ...        ...  ..   ...             ...      ...       ...      ...     ...
# 42360  제주_서귀포시  제주  서귀포시  재활용 가능자원  분리배출  폐전기전자제품       NaN   1027.6     0.0
# 42361  제주_서귀포시  제주  서귀포시  재활용 가능자원  분리배출     폐가구류       NaN      0.0     0.0
# 42362  제주_서귀포시  제주  서귀포시  재활용 가능자원  분리배출       기타       NaN    200.0     0.0
# 42363  제주_서귀포시  제주  서귀포시  재활용 가능자원  분리배출  재활용 잔재물       NaN      0.0  1627.4
# 42364  제주_서귀포시  제주  서귀포시   음식물류 폐기물 분리배출      NaN       NaN  30650.4     0.0
#
#            매립   기타      발생량    연도
# 0      4672.0  0.0  13797.0  2019
# 1      2737.5  0.0   8103.0  2019
# 2        73.0  0.0    255.5  2019
# 3       255.5  0.0    766.5  2019
# 4       365.0  0.0   1058.5  2019
# ...       ...  ...      ...   ...
# 42360     0.0  0.0   1027.6  2023
# 42361     0.0  0.0      0.0  2023
# 42362     0.0  0.0    200.0  2023
# 42363   718.0  0.0   2345.4  2023
# 42364     0.0  0.0  30650.4  2023
#
# [42365 rows x 12 columns]

# %%
## 쓰레기 데이터와 가구, 전입출 행정구역 비교 2번째째

# %%
house = pd.read_csv('../../DB/가구원수별_시군구명변경.csv', encoding = 'utf-8')

# %%
house
# Out:
#       Unnamed: 0    행정구역    시점  시도  시군구     1인     2인     3인     4인 5인 이상
# 0              0  강원_강릉시  2019  강원  강릉시  32119  28629  16547  11083  3715
# 1              1  강원_강릉시  2020  강원  강릉시  37635  29649  16499  10810  3439
# 2              2  강원_강릉시  2021  강원  강릉시  38581  30768  16191  10369  3196
# 3              3  강원_강릉시  2022  강원  강릉시  37485  31207  16149   9929  2893
# 4              4  강원_강릉시  2023  강원  강릉시  39349  31555  15881   9526  2607
# ...          ...     ...   ...  ..  ...    ...    ...    ...    ...   ...
# 1150        1150  충북_충주시  2019  충북  충주시  30972  27619  16713  10954  3933
# 1151        1151  충북_충주시  2020  충북  충주시  33557  28496  16470  11058  3501
# 1152        1152  충북_충주시  2021  충북  충주시  35774  29809  15926  10638  3203
# 1153        1153  충북_충주시  2022  충북  충주시  36621  30628  15892  10025  2964
# 1154        1154  충북_충주시  2023  충북  충주시  38242  31137  15885   9654  2791
#
# [1155 rows x 10 columns]

# %%
print(set(house['행정구역'].unique())-set(waste['행정구역'].unique()))
print(set(waste['행정구역'].unique()) - set(house['행정구역'].unique()))
# Out:
# {'경북_남구', '경북_북구', '경북_군위군'}
# set()

# %% [markdown]
# ### {'경북_군위군', '경북_북구', '경북_남구'}

# %% [markdown]
# - 군위군은 대구 군위군으로 변경

# %%
house['시도'][house['행정구역'] == "경북_군위군"] = '대구'
house['행정구역'][house['행정구역'] == "경북_군위군"] = '대구_군위군'
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_21132\1188093464.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   house['시도'][house['행정구역'] == "경북_군위군"] = '대구'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_21132\1188093464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['시도'][house['행정구역'] == "경북_군위군"] = '대구'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_21132\1188093464.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   house['행정구역'][house['행정구역'] == "경북_군위군"] = '대구_군위군'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_21132\1188093464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house['행정구역'][house['행정구역'] == "경북_군위군"] = '대구_군위군'

# %%
house[house['행정구역'] == "대구_군위군"]
# Out:
#      Unnamed: 0    행정구역    시점  시도  시군구    1인    2인    3인   4인 5인 이상
# 355         355  대구_군위군  2019  대구  군위군  3985  4160  1504  628   283
# 356         356  대구_군위군  2020  대구  군위군  4111  4275  1451  625   264
# 357         357  대구_군위군  2021  대구  군위군  4426  4249  1378  513   231
# 358         358  대구_군위군  2022  대구  군위군  4683  4375  1392  507   228
# 484         484  대구_군위군  2023  대구  군위군  3874  5094  1311  467   197

# %% [markdown]
# - 경북_북구, 경북_남구 삭제

# %%
house_1 = house[~((house['행정구역']=='경북_북구')|(house['행정구역']=='경북_남구'))]

# %%
house_1 = house_1.iloc[:,1:]

# %%
# house_1.to_csv('../../DB/가구원수별_시군구명변경(수정).csv',encoding = 'CP949', index=False)

# %%
moving = pd.read_csv('../../DB/전입출_시군구명변경.csv', encoding = 'utf-8')

# %%
moving
# Out:
#       Unnamed: 0    행정구역    시점  시도  시군구  총전입 (명)  총전출 (명)  순이동 (명)
# 0              0  강원_강릉시  2019  강원  강릉시    31980    30787     1193
# 1              1  강원_강릉시  2020  강원  강릉시    31595    30983      612
# 2              2  강원_강릉시  2021  강원  강릉시    31820    30668     1152
# 3              3  강원_강릉시  2022  강원  강릉시    25320    25598     -278
# 4              4  강원_강릉시  2023  강원  강릉시    23710    24529     -819
# ...          ...     ...   ...  ..  ...      ...      ...      ...
# 1371        1497  충북_충주시  2020  충북  충주시    29948    29887       61
# 1372        1498  충북_충주시  2021  충북  충주시    29990    29510      480
# 1373        1499  충북_충주시  2022  충북  충주시    24920    24727      193
# 1374        1500  충북_충주시  2023  충북  충주시    25753    25169      584
# 1375        1501  충북_충주시  2024  충북  충주시    25142    24661      481
#
# [1376 rows x 8 columns]

# %%
print(set(moving['행정구역'].unique())-set(waste['행정구역'].unique()))
print(set(waste['행정구역'].unique()) - set(moving['행정구역'].unique()))
# Out:
# {'경북_군위군'}
# set()

# %%
moving[moving['시군구'] == "군위군"]
# Out:
#      Unnamed: 0    행정구역    시점  시도  시군구  총전입 (명)  총전출 (명)  순이동 (명)
# 426         510  경북_군위군  2019  경북  군위군     2226     2054      172
# 427         511  경북_군위군  2020  경북  군위군     2125     2422     -297
# 428         512  경북_군위군  2021  경북  군위군     2113     2026       87
# 429         513  경북_군위군  2022  경북  군위군     2423     1652      771
# 430         514  경북_군위군  2023  경북  군위군        0        0        0
# 431         515  경북_군위군  2024  경북  군위군        0        0        0
# 570         654  대구_군위군  2023  대구  군위군     1771     1737       34
# 571         655  대구_군위군  2024  대구  군위군     1648     1816     -168

# %%
moving[moving['행정구역'] == "경북_남구"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 행정구역, 시점, 시도, 시군구, 총전입 (명), 총전출 (명), 순이동 (명)]
# Index: []

# %%
moving.drop([430, 431], axis= 0, inplace=True)
moving[moving['시군구'] == "군위군"]
# Out:
#      Unnamed: 0    행정구역    시점  시도  시군구  총전입 (명)  총전출 (명)  순이동 (명)
# 426         510  경북_군위군  2019  경북  군위군     2226     2054      172
# 427         511  경북_군위군  2020  경북  군위군     2125     2422     -297
# 428         512  경북_군위군  2021  경북  군위군     2113     2026       87
# 429         513  경북_군위군  2022  경북  군위군     2423     1652      771
# 570         654  대구_군위군  2023  대구  군위군     1771     1737       34
# 571         655  대구_군위군  2024  대구  군위군     1648     1816     -168

# %%
moving['시도'][moving['행정구역'] == "경북_군위군"] = '대구'
moving['행정구역'][moving['행정구역'] == "경북_군위군"] = '대구_군위군'
# Out:
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\1584931641.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   moving['시도'][moving['행정구역'] == "경북_군위군"] = '대구'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\1584931641.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moving['시도'][moving['행정구역'] == "경북_군위군"] = '대구'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\1584931641.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   moving['행정구역'][moving['행정구역'] == "경북_군위군"] = '대구_군위군'
# C:\Users\nammi\AppData\Local\Temp\ipykernel_24392\1584931641.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   moving['행정구역'][moving['행정구역'] == "경북_군위군"] = '대구_군위군'

# %%
moving.to_csv("DB/전입출_시군구명변경(수정).csv", encoding='CP949', index=False)
